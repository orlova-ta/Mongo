# %%
from mongo_connection import connect
client = connect()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from mongo_connection import connect
#       2 client = connect()
#
# File c:\Users\t006918\Mongo\mongo_connection.py:1
# ----> 1 from pymongo import MongoClient
#       2 from dotenv import load_dotenv
#       3 import os
#
# ModuleNotFoundError: No module named 'pymongo'

# %%
#print all collections in cities_db
db = client["world_cities_DB"]
print(db.list_collection_names())

#client.list_database_names()   can work without print
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 #print all collections in cities_db
# ----> 2 db = client["world_cities_DB"]
#       3 print(db.list_collection_names())
#
# NameError: name 'client' is not defined

# %%
#regular expression for step 6
lista = ["Japan", "japan", "JAPAN"]

# %%
fi_cities = {"$regex":"Fi"}
docs = colls.find({"country": fi_cities}).distinct("country")
for doc in docs:
    print(doc)

# %%
docs = coll.find({"population": {"$lt":10, "$gt":0}})
for doc in docs:
    print(doc["city"], int (doc["population"]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 docs = coll.find({"population": {"$lt":10, "$gt":0}})
#       2 for doc in docs:
#       3     print(doc["city"], int (doc["population"]))
#
# NameError: name 'coll' is not defined

# %%
s_ending_cities = {"$regex":".s$"}
docs = coll.find({"city":s_ending_cities}).sort(sort"city",-1)
for doc in dics:
    print(doc["city"])
# Out:
#   Cell In[1], line 2
#     docs = coll.find({"city":s_ending_cities}).sort(sort"city",-1)
#                                                         ^
# SyntaxError: invalid syntax

# %%
#19
docs = coll.find({"imdb.rating": {"$gte": 8.5}}).sort("imdb.rating", -1)
for doc in docs:
    print(doc["title"], doc["imdb"]["rating"])

# %%
#20
docs = coll.find({"$or":
                  [
                    {"imdb.rating":{"$gte:9.0"}}
                    {"imdb.rating": {"$lte:3.0"}}  
                  ]})
for doc in docs:
    print(doc["title"], doc["imdb"]["rating"])
